# %%
# Install dependecies
# %pip install anthropic python-dotenv

# %%
# Load env variables
from dotenv import load_dotenv

load_dotenv()

# %%
# Create an API client
from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-0"

# %%
# Make a request

# use a helper function to create messages and store them since API doesnt keep track of message/response
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

# helper function to add in assistant messages
def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages, system=None):
    
    params = {
        "model"="model,
        "max_tokens"="1000,
        "messages"="messages
    }

    if system:
        params["system] = system

    message = client.messages.create(**params)
    
    # print out the message returned by Claude
    message.content[0].text

# %%
 message = []

system = """
    You are patient math tutor.
    Do not directly answer a student's questions.
    Guide them to a solution step by step.
    """

add_user_message(messages, "How do I solve 5x+2=2 for x?")

answer = chat(messages, system=system)
